# %% [raw]
# Q 1. What does RGBA stand for?
# ANSWER:-
# RGBA stands for "Red, Green, Blue, Alpha" and is a color model used in computer graphics and image processing.
#
#
#
#
# Q 2. From the Pillow module, how do you get the RGBA value of any images?
# ANSWER:-
# To get the RGBA value of any image using the Pillow module in Python, we can use the `getpixel()` method of the `Image` class. This method returns the pixel value at a specified position in the image as a tuple of RGBA values.
#
#
#
#
# Q 3. What is a box tuple, and how does it work?
# ANSWER:-
# A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively.
#
#
#
#
# Q 4. Use your image and load in notebook then, How can you find out the width and height of an Image object?
# ANSWER:-
# To find out the width and height of an `Image` object using the Pillow module in Python, we can use the `size` attribute of the `Image` object.
#
# Here's an example:
#
# ```python
# from PIL import Image
#
# # Open the image file
# img = Image.open("my_image.png")
#
# # Get the size of the image (width, height)
# width, height = img.size
#
# # Print the width and height
# print(f"The image size is {width}x{height} pixels.")
# ```
#
#
#
#
#
#
# Q 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?
# ANSWER:-
# img.crop((0, 50, 50, 50)) #Notice that you are passing a box tuple to crop(), not four separate integer arguments.
#
#
#
#
# Q 6. After making changes to an Image object, how could you save it as an image file?
# ANSWER:-
# To save changes made to an `Image` object as an image file using the Pillow module in Python, we can use the `save()` method of the `Image` class. This method takes a filename as an argument and saves the image to that file.
#
# Here's an example:
#
# ```python
# from PIL import Image
#
# # Open the original image
# img = Image.open("my_image.png")
#
# # Apply a rotation transformation
# rotated_img = img.rotate(45)
#
# # Save the rotated image to a new file
# rotated_img.save("my_rotated_image.png")
# ```
#
#
#
# Q 7. What module contains Pillow’s shape-drawing code?
# ANSWER:-
# The ImageDraw module contains code to draw on images.
#
#
#
#
# Q 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?
# ANSWER:-
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). They are returned by passing the Image object to the ImageDraw.Draw() function.
