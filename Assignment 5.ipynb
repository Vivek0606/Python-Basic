# %% [raw]
# Q 1. What does an empty dictionary's code look like?
# ANSWER:-
# An empty dictionary's code look like two curly brackets: {}
#
#
#
#
#
# Q 2. What is the value of a dictionary value with the key 'foo' and the value 42?
# ANSWER:-
# dic = {'foo' : 42}
# dic
# OUTPUT:- {'foo': 42}
#
#
#
#
#
# Q 3. What is the most significant distinction between a dictionary and a list?
# ANSWER:-
# The items in a list are ordered items, while the items stored in a dictionary are unordered
#
#
#
#
#
# Q 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
# ANSWER:-
# spam = {'bar': 100}
# spam['foo']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\VIVEKP~1\AppData\Local\Temp/ipykernel_7060/414641506.py in <module>
#       1 spam = {'bar': 100}
# ----> 2 spam['foo']
#
# KeyError: 'foo'
#
#
#
#
#
# Q 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
# ANSWER:-
# If a dictionary is stored in spam, the expressions 'cat' in spam and 'cat' in spam.keys() are equivalent and will both check whether the string 'cat' is a key in the dictionary.
#
#
#
#
#
# Q 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
# ANSWER:-
# If a dictionary is stored in `spam`, the expressions `'cat' in spam` and `'cat' in spam.values()` are not equivalent and will check for different things.
#
# The expression `'cat' in spam` will check whether the string `'cat'` is a key in the dictionary, whereas the expression `'cat' in spam.values()` will check whether the string `'cat'` is a value in the dictionary.
#
#
#
#
#
# Q 7. What is a shortcut for the following code?
# if 'color' not in spam:
# spam['color'] = 'black'
# ANSWER:-
# spam.setdefault('color', 'black')
#
#
#
#
#
# Q 8. How do you "pretty print" dictionary values using which module and function?
# ANSWER:-
# To "pretty print" dictionary values in Python, you can use the built-in pprint module and its pprint() function. This function prints the dictionary in a nicely formatted way that is easier to read and understand than the default print() function.
